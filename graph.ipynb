# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

data = pd.read_csv('data.csv')
#select rows where country name is 'United States' or 'Euro area' or 'China'
data = data[(data['Country Name'] == 'United States') | (data['Country Name'] == 'European Union') | (data['Country Name'] == 'China') | (data['Country Name'] == 'Brazil')]
data.head()
# Out:
#        Country Name Country Code
# 29           Brazil          BRA  \
# 40            China          CHN
# 73   European Union          EUU
# 251   United States          USA
#
#                                         Indicator Name  Indicator Code  1960
# 29   Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN  \
# 40   Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# 73   Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
# 251  Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS   NaN
#
#           1961        1962        1963        1964        1965  ...
# 29   11.427290   10.600737   12.062300    9.821185   10.832317  ...  \
# 40    7.040823    9.598448   12.118208   16.328319   25.415292  ...
# 73   97.396151  102.373696  109.983262  119.548240  127.904057  ...
# 251  41.334278   46.725537   51.064834   55.029481   61.038199  ...
#
# ...

# %%
"""
Cell generated by Data Wrangler.
"""
def clean_data(data):
    # Drop column: '1960'
    data = data.drop(columns=['1960'])
    # Drop column: '2021'
    data = data.drop(columns=['2021'])
    # Drop column: '2022'
    data = data.drop(columns=['2022'])
    # Drop column: 'Unnamed: 67'
    data = data.drop(columns=['Unnamed: 67'])
    return data

data_clean = clean_data(data.copy())
data_clean.head()
# Out:
#        Country Name Country Code
# 29           Brazil          BRA  \
# 40            China          CHN
# 73   European Union          EUU
# 251   United States          USA
#
#                                         Indicator Name  Indicator Code
# 29   Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS  \
# 40   Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS
# 73   Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS
# 251  Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS
#
#           1961        1962        1963        1964        1965        1966
# 29   11.427290   10.600737   12.062300    9.821185   10.832317   10.506927  \
# 40    7.040823    9.598448   12.118208   16.328319   25.415292   36.460427
# 73   97.396151  102.373696  109.983262  119.548240  127.904057  135.993094
# 251  41.334278   46.725537   51.064834   55.029481   61.038199   69.243506
#
# ...

# %%
"""
Cell generated by Data Wrangler.
"""
def clean_data(data_clean):
    # Drop column: 'Indicator Code'
    data_clean = data_clean.drop(columns=['Indicator Code'])
    return data_clean

data_clean_1 = clean_data(data_clean.copy())
data_clean_1.head()
# Out:
#        Country Name Country Code
# 29           Brazil          BRA  \
# 40            China          CHN
# 73   European Union          EUU
# 251   United States          USA
#
#                                         Indicator Name       1961        1962
# 29   Fertilizer consumption (kilograms per hectare ...  11.427290   10.600737  \
# 40   Fertilizer consumption (kilograms per hectare ...   7.040823    9.598448
# 73   Fertilizer consumption (kilograms per hectare ...  97.396151  102.373696
# 251  Fertilizer consumption (kilograms per hectare ...  41.334278   46.725537
#
#            1963        1964        1965        1966        1967  ...
# 29    12.062300    9.821185   10.832317   10.506927   16.711749  ...  \
# 40    12.118208   16.328319   25.415292   36.460427   26.567764  ...
# 73   109.983262  119.548240  127.904057  135.993094  150.753301  ...
# 251   51.064834   55.029481   61.038199   69.243506   76.234804  ...
#
# ...

# %%
brazil = data_clean_1[data_clean_1['Country Name'] == 'Brazil']
china = data_clean_1[data_clean_1['Country Name'] == 'China']
euro = data_clean_1[data_clean_1['Country Name'] == 'European Union']
usa = data_clean_1[data_clean_1['Country Name'] == 'United States']

#remove indexs of countries
china = china.reset_index(drop=True)
euro = euro.reset_index(drop=True)
usa = usa.reset_index(drop=True)
brazil = brazil.reset_index(drop=True)

brazil.head()
# Out:
#   Country Name Country Code
# 0       Brazil          BRA  \
#
#                                       Indicator Name      1961       1962
# 0  Fertilizer consumption (kilograms per hectare ...  11.42729  10.600737  \
#
#       1963      1964       1965       1966       1967  ...        2011
# 0  12.0623  9.821185  10.832317  10.506927  16.711749  ...  251.427319  \
#
#          2012        2013        2014        2015        2016        2017
# 0  230.132479  265.567782  285.060536  234.965084  240.181951  275.933902  \
#
#          2018        2019        2020
# 0  293.864762  296.727982  365.240914
#
# [1 rows x 63 columns]

# %%
"""
Cell generated by Data Wrangler.
"""
def clean_data(brazil):
    # Drop column: 'Country Name'
    brazil = brazil.drop(columns=['Country Name'])
    # Drop column: 'Country Code'
    brazil = brazil.drop(columns=['Country Code'])
    # Drop column: 'Indicator Name'
    brazil = brazil.drop(columns=['Indicator Name'])
    return brazil

brazil_clean = clean_data(brazil.copy())
china_clean = clean_data(china.copy())
euro_clean = clean_data(euro.copy())
usa_clean = clean_data(usa.copy())

# %%
usa_values = np.array(usa_clean)
china_values = np.array(china_clean)
euro_values = np.array(euro_clean)
brazil_values = np.array(brazil_clean)
usa_values = usa_values.flatten()
china_values = china_values.flatten()
euro_values = euro_values.flatten()
brazil_values = brazil_values.flatten()
xticks = [x for x in range(1961, 2021)]

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots()
fig.set_dpi(200)
fig.set_size_inches(6, 4)
ax.plot(xticks, usa_values, label='United States')
ax.plot(xticks, china_values, label='China')
ax.plot(xticks, euro_values, label='European Union')
ax.plot(xticks, brazil_values, label='Brazil')
ax.xaxis.set_major_locator(MultipleLocator(10))
ax.xaxis.set_major_formatter('{x:.0f}')
ax.xaxis.set_minor_locator(MultipleLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(50))
ax.yaxis.set_minor_locator(MultipleLocator(25))
plt.xlabel('Years')
plt.ylabel('fertilizer use (Mt/ha)')
plt.ylim(0,500)
plt.xlim(1960, 2020)
plt.legend(loc= 2, labelcolor='black')
plt.show()
